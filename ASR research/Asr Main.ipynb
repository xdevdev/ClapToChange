# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np 
import wave
import sys

# %%
from scipy.io import wavfile as wav

rate, data = wav.read('test1.wav')
# %matplotlib inline
plt.plot(data)
plt.show()

# %%
rate, data = wav.read('test2.wav')
# %matplotlib inline
plt.plot(data)
plt.show()

# %%
rate, data = wav.read('test3.wav')
# %matplotlib inline
plt.plot(data)
plt.show()

# %%
rate, data = wav.read('test4.wav')
# %matplotlib inline
plt.plot(data)
plt.show()

# %%
rate, data = wav.read('test5.wav')
# %matplotlib inline
plt.plot(data)
plt.show()

# %%
data_test = wav.read('test1.wav')

# %%
data.shape
# Out:
# (585216, 2)
